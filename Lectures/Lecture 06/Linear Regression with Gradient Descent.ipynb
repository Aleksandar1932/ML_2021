# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
from sklearn.linear_model import SGDRegressor

# %% [markdown]
# # Generate random dataset

# %%
X,Y = make_regression(n_features=1,n_samples=100)

# %%
X = X.reshape(-1,1)

# %%
Y = Y.reshape(1,-1)

# %%
# X = np.random.rand(100,1)
# Y = np.random.rand(100,1)

# %%
plt.scatter(X, Y)
plt.title("Random dataset")
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# # Linear Regression with Gradient Descent

# %%
reg = SGDRegressor(max_iter=5)
reg.fit(X,y)
# Out:
# d:\projects\pycharmprojects\ml_2021\venv2\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1220: ConvergenceWarning:
#
# Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
# SGDRegressor(max_iter=5)

# %%
axes = plt.gca()
x_vals = np.array(axes.get_xlim())
y_vals = reg.intercept_[0] + reg.coef_[0] * x_vals
plt.plot(x_vals, y_vals, '-')
plt.scatter(X, Y)
plt.title("Random dataset")
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
